# %% [markdown]
# <a href="https://colab.research.google.com/github/coldsober-irene/NLP-fellowship/blob/main/GIB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import json
#import math
from google.colab import drive

# %%
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# DAY 1: JSON DATA (Javascript Object Notation)

# %% [markdown]
# functions of json
# 1. dump
# 2. dumps
# 3. load
# 4. loads

# %%
# dump
d1 = '''{"name":"GB", "age":19.5}'''
d2 = {"name":"GB", "age":19.5}
d3 = [1,2,3,4,5]
d4 = 12
d5 = 12.5
d6 = (3,34,56,7)
js1 = json.dumps(d1)
js2 = json.dumps(d2)

# %%
with open("belize.json", "w") as f:
  json.dump("""{"key1":[{"name":"irene"}, 20]}""", f)

# %% [markdown]
# LOADS vs LOAD

# %%
# loads
js_str = """{"key1":[{"name":"irene"}, 20]}"""
py_str = json.loads(js_str)
print(py_str['key1'][0]["name"]) 
# print()
# Out:
# irene

# %%
# load
f = open("/content/belize.json")
# print(f)
data = json.load(f)
print(data)
f.close()
# Out:
# {"key1":[{"name":"irene"}, 20]}

# %% [markdown]
# DAY 2: WEB SCRAPING

# %%
# from bs4 import BeautifulSoup
from bs4 import BeautifulSoup as p
import requests as r

open_web = r.get("https://www.geeksforgeeks.org/read-json-file-using-python/")
# open_web = r.get("https://www.faranux.com/product-category/component/potentiometer/")
soup = p(open_web.text, "html.parser")
print(soup.prettify())
# Out:
# <!DOCTYPE doctype html>
# <html lang="en-us" prefix="og: http://ogp.me/ns#">
#  <meta charset="utf-8"/>
#  <meta content="Data Structures,Algorithms,Python,Java,C,C++,JavaScript,Android Development,SQL,Data Science,Machine Learning,PHP,Web Development,System Design,Tutorial,Technical Blogs,Interview Experience,Interview Preparation,Programming,Competitive Programming,SDE Sheet,Job-a-thon,Coding Contests,GATE CSE,HTML,CSS,React,NodeJS,Placement,Aptitude,Quiz,Computer Science,Programming Examples,GeeksforGeeks Courses,Puzzles" name="keywords"/>
#  <meta content="width=device-width,initial-scale=1,maximum-scale=1" name="viewport"/>
#  <link href="https://media.geeksforgeeks.org/wp-content/cdn-uploads/gfg_favicon.png" rel="shortcut icon" type="image/x-icon"/>
#  <meta content="#308D46" name="theme-color"/>
#  <meta content="https://media.geeksforgeeks.org/wp-content/cdn-uploads/gfg_200x200-min.png" name="image" property="og:image"/>
# ...

# %%
print(soup.body.prettify())
# Out:
# <body class="post-template-default single single-post postid-367055 single-format-standard custom-background custom-background-white">
#  <script>
#   const gfgThemeList=Object.freeze({LIGHT:"gfgThemeLight",DARK:"gfgThemeDark"}),getThemeFromCookie=()=>{let a="",c=document.cookie,b=c.split(";");for(let c=0;c<b.length;c++){let d=b[c].split("=");d[0].trim()=="gfg_theme"&&(a=d[1].trim())}return a};var isDarkMode=getThemeFromCookie()==gfgThemeList.DARK;document.querySelector("body").setAttribute("data-dark-mode",isDarkMode)
#  </script>
#  <div class="header-main__wrapper">
#   <a class="gfg-stc" href="#main" style="top:0">
#    Skip to content
#   </a>
#   <a aria-label="Logo" class="header-main__logo" href="https://www.geeksforgeeks.org/">
#    <div class="_logo">
#     <img alt="geeksforgeeks" class="gfg_logo_img" src="https://media.geeksforgeeks.org/gfg-gg-logo.svg"/>
#    </div>
#   </a>
#   <div class="header-main__container">
#    <span class="hamburger-menu">
# ...

# %%
for text in [i.get_text() for i in soup.body.find_all("p")]:
  print(text)
# Out:
# The full-form of JSON is JavaScript Object Notation. It means that a script (executable) file which is made of text in a programming language, is used to store and transfer the data. Python supports JSON through a built-in package called json. To use this feature, we import the json package in Python script. The text in JSON is done through quoted-string which contains the value in key-value mapping within { }.
# It’s pretty easy to load a JSON object in Python. Python has a built-in package called json, which can be used to work with JSON data. It’s done by using the JSON module, which provides us with a lot of methods which among loads() and load() methods are gonna help us to read the JSON file.
# ...

# %%
# 
link_p = "https://igihe.com/"
link_p2 = "https://web.archive.org/web/20220214075742/https://www.igihe.com/"

page = r.get(link_p2).text
s = p(page, "html.parser")
# print(s.prettify())

parent_div = s.find("div", class_ = "col col-lg-4 col-md-4 col-sm-5")
spans = parent_div.find_all("span", class_ = "homenews-title")
# Out:
# 64

# %%
links = []
for span in spans:
  links.append(span.find('a'))
links

# %%
link_titles = []
for link in links:
  link_titles.append(link['href'])
link_titles

# %%
x = "Gahongayire "
full_names = x + "Belise"
full_names
# Out:
# 'Gahongayire Belise'

# %%
url_and_title = []
for title in link_titles:
  url_and_title.append(link_p2+title)
url_and_title

# %%
returned = []
for url in url_and_title:
  returned.append(r.get(url).text)

returned

# %%
main_text = []
for page_text in returned:
  soup = p(page_text, "html.parser")
  main_div = soup.find("div", class_ = "fulltext margintop10")
  paragraphs = main_div.find_all("p")
  for paragraph in paragraphs:
    main_text.append(paragraph.get_text())

# %%
for text in main_text:
  print(text)

# %%
# TURN PARAGRAPHS INTO TXT FILE
with open("irene_belize.txt", "w") as f:
  for line in main_text:
    f.write(line+"\n")
