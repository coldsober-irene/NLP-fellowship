# %% [markdown]
# <a href="https://colab.research.google.com/github/coldsober-irene/NLP-fellowship/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
from google.colab import drive
import os

# %%
# mount the drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# csv data 
data_path = "/content/drive/MyDrive/NLP fellowship/self study"
os.chdir(data_path)

# !ls
files = []
for file in os.listdir(data_path):
  if ".csv" in file:
    files.append(file)
# Out:
# machine-readable-business-employment-data-june-2022-quarter.csv

# %%
# read csv file with pandas
csv = pd.read_csv(os.path.join(data_path, files[0]))
# see top head 5 rows
csv.head()
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number          0
# 1      BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number          0
# 2      BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number          0
# 3      BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number          0
# 4      BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number          0
#
#                           Subject                            Group  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
# 2  Business Data Collection - BDC  Industry by employment variable
# 3  Business Data Collection - BDC  Industry by employment variable
# 4  Business Data Collection - BDC  Industry by employment variable
#
#   Series_title_1                     Series_title_2 Series_title_3  \
# ...

# %%
# get top 20 rows
csv.head(20)
# Out:
#    Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0       BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number          0
# 1       BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number          0
# 2       BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number          0
# 3       BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number          0
# 4       BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number          0
# 5       BDCQ.SEA1AA  2012.09     79261.0        NaN      F  Number          0
# 6       BDCQ.SEA1AA  2012.12     87793.0        NaN      F  Number          0
# 7       BDCQ.SEA1AA  2013.03     91571.0        NaN      F  Number          0
# 8       BDCQ.SEA1AA  2013.06     81687.0        NaN      F  Number          0
# 9       BDCQ.SEA1AA  2013.09     81471.0        NaN      F  Number          0
# 10      BDCQ.SEA1AA  2013.12     93950.0        NaN      F  Number          0
# ...

# %%
# get last 5 rows
csv.tail()
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 20249    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 20250    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 20251    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 20252    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 20253    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 20249          0  Business Data Collection - BDC
# 20250          0  Business Data Collection - BDC
# 20251          0  Business Data Collection - BDC
# 20252          0  Business Data Collection - BDC
# 20253          0  Business Data Collection - BDC
#
#                                               Group  \
# 20249  Territorial authority by employment variable
# 20250  Territorial authority by employment variable
# 20251  Territorial authority by employment variable
# ...

# %%
# get last 100 rows
csv.tail(100)
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 20154    BDCQ.SEE3075A  2016.03     24498.0        NaN      F  Number
# 20155    BDCQ.SEE3075A  2016.06     24311.0        NaN      F  Number
# 20156    BDCQ.SEE3075A  2016.09     24088.0        NaN      F  Number
# 20157    BDCQ.SEE3075A  2016.12     24763.0        NaN      F  Number
# 20158    BDCQ.SEE3075A  2017.03     24445.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 20249    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 20250    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 20251    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 20252    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 20253    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 20154          0  Business Data Collection - BDC
# ...

# %%
# get all columns of the data frame
cols = csv.columns
cols
# Out:
# Index(['Series_reference', 'Period', 'Data_value', 'Suppressed', 'STATUS',
#        'UNITS', 'Magnitude', 'Subject', 'Group', 'Series_title_1',
#        'Series_title_2', 'Series_title_3', 'Series_title_4', 'Series_title_5'],
#       dtype='object')

# %%
# get data of the single column
single_col = csv['Period']
single_col
# Out:
# 0        2011.06
# 1        2011.09
# 2        2011.12
# 3        2012.03
# 4        2012.06
#           ...
# 20249    2017.06
# 20250    2017.09
# 20251    2017.12
# 20252    2018.03
# 20253    2018.06
# Name: Period, Length: 20254, dtype: float64

# %% [markdown]
# create the dataframe from python dict

# %%
dictionary = {"name":"irene", 
              "age":30, "district": 
              "Nyarugenge", "std":[20, 30, 40, 120, 90]
              }
df = pd.DataFrame.from_dict(dictionary)
df.head()
# Out:
#     name  age    district  std
# 0  irene   30  Nyarugenge   20
# 1  irene   30  Nyarugenge   30
# 2  irene   30  Nyarugenge   40
# 3  irene   30  Nyarugenge  120
# 4  irene   30  Nyarugenge   90

# %%
# edit some data
df["std"][0] = "coldsober"
df.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#     name  age    district        std
# 0  irene   30  Nyarugenge  coldsober
# 1  irene   30  Nyarugenge         30
# 2  irene   30  Nyarugenge         40
# 3  irene   30  Nyarugenge        120
# 4  irene   30  Nyarugenge         90

# %%
# not included in the main contents
import json

with open("myJson.json", "w") as f:
  json.dump(dictionary, f)

# %%
# get the data from it
with open("myJson.json", "r") as f:
  d = json.load(f)
  print(d, type(d))
# Out:
# {'name': 'irene', 'age': 30, 'district': 'Nyarugenge', 'std': [20, 30, 40, 120, 90]} <class 'dict'>

# %%
json_str = """
              {"name":"irene", 
              "age":30, "district": 
              "Nyarugenge", "std":[20, 30, 40, 120, 90]
              }
            """

# %%
d = json.loads(json_str)
print(type(d))
# Out:
# <class 'dict'>

# %%
this = json.dumps(json_str)
print(this, type(this))
# Out:
# "\n              {\"name\":\"irene\", \n              \"age\":30, \"district\": \n              \"Nyarugenge\", \"std\":[20, 30, 40, 120, 90]\n              }\n            " <class 'str'>
